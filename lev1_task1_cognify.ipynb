# %%
import os
os.listdir(r"C:\Users\HP\Downloads")
# Out:
# ['.ipynb_checkpoints',
#  '1.TINY CODERS.pptx',
#  '1747230991.pdf',
#  'abac260b-055d-402f-9b70-f5e7c332a298 (1).xlsx',
#  'abac260b-055d-402f-9b70-f5e7c332a298.xlsx',
#  'ab_test_summary (1).xls',
#  'ab_test_summary.xls',
#  'Activities on MS Excel Tools (DCE).xlsx',
#  'AI_Developer_3_Month_Roadmap.pdf',
#  'amazon_sales_analysis.xlsx',
#  'app.py',
#  'archive',
#  'archive (1)',
#  'archive (1).zip',
#  'archive (10)',
#  'archive (10).zip',
#  'archive (11)',
#  'archive (11).zip',
#  'archive (12)',
#  'archive (12).zip',
#  'archive (13)',
#  'archive (13).zip',
#  'archive (14)',
#  'archive (14).zip',
#  'archive (15)',
#  'archive (15).zip',
#  'archive (16)',
#  'archive (16).zip',
#  'archive (17)',
#  'archive (17).zip',
#  'archive (18)',
#  'archive (18).zip',
#  'archive (2)',
#  'archive (2).zip',
#  'archive (3)',
#  'archive (3).zip',
#  'archive (4)',
#  'archive (4).zip',
#  'archive (5)',
#  'archive (5).zip',
#  'archive (6)',
#  'archive (6).zip',
# ...

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\HP\Downloads\Dataset .csv")

df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
top3 = df['Cuisines'].value_counts().head(3)
top3
# Out:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Name: count, dtype: int64

# %%
percentage = (top3 / len(df)) * 100

result_task1 = pd.DataFrame({
    'Restaurant_Count': top3,
    'Percentage (%)': percentage.round(2)
})

result_task1
# Out:
#                        Restaurant_Count  Percentage (%)
# Cuisines
# North Indian                        936            9.80
# North Indian, Chinese               511            5.35
# Chinese                             354            3.71
